# %%
import pandas as pd

io = r'..\Level 3 &VS scorecard.xlsx'

# %%
data = pd.read_excel(io, sheet_name = 1)
data.head()
# Out:
# D:\HT_APPDATA\anaconda\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#    Unnamed: 0 Scorecard Unnamed: 2 Unnamed: 3                    Unnamed: 4  \
# 0         NaN       NaN        NaN        NaN                           NaN
# 1         NaN      PQVC      指标分类1       Area                          指标名称
# 2         NaN         S        RIF        all                 RIF - L&SLHEX
# 3         NaN         S      LTCFR        all                 LTCFR-L&SLHEX
# 4         NaN         S        BIS       Assy  安全Missed 缺陷(Year End )-Assy
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Projects  ...  Unnamed: 11  \
# 0        NaN        NaN        NaN         NaN      NaN  ...          NaN
# 1     公司级目标值    Level 2    Level 3         NaN  Level 3  ...        Owner
# 2          0          0          0         NaN        Y  ...        Peter
# ...
